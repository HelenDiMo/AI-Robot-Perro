# %% [markdown]
# <a href="https://colab.research.google.com/github/Anasfady/AI-Robot-Perro/blob/main/AI%20Robot%20Perro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
inventario = 100
print(f"El inventario contiene {inventario} hamburguesas")

while inventario > 0:
    if inventario <= 10:
        print("ADVERTENCIA: EL INVENTARIO ESTÁ CASI VACÍO")

    num_hamburguesas = int(input("¿Cuántas hamburguesas desea comprar? "))

    if num_hamburguesas > inventario:
        print(f"No hay suficientes hamburguesas, solo quedan {inventario} disponibles.")
    else:
        inventario -= num_hamburguesas
        print(f"Venta realizada. Quedan {inventario} hamburguesas.")

print("Inventario agotado. Cerrando tienda.")
# Out:
# El inventario contiene 100 hamburguesas
# Venta realizada. Quedan 98 hamburguesas.
# Venta realizada. Quedan 91 hamburguesas.
# Venta realizada. Quedan 85 hamburguesas.
# Venta realizada. Quedan 83 hamburguesas.
# Venta realizada. Quedan 61 hamburguesas.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_190/2904891983.py in <cell line: 0>()
#       6         print("ADVERTENCIA: EL INVENTARIO ESTÁ CASI VACÍO")
#       7
# ----> 8     num_hamburguesas = int(input("¿Cuántas hamburguesas desea comprar? "))
#       9
#      10     if num_hamburguesas > inventario:
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
# ...

# %%
battery_level = 90
is_plugged_in = True

print(f"Initial charge: {battery_level}%")

while battery_level < 100:
    battery_level += 2

    if battery_level > 100:
        battery_level = 100

    print(f"Charging... {battery_level}%")

    if battery_level == 100:
        print("⚡ Battery Full! Please unplug.")
    elif battery_level >= 95:
        print("Finalizing trickle charge...")

print("System: Protection mode active. Charging stopped.")
# Out:
# Initial charge: 90%
# Charging... 92%
# Charging... 94%
# Charging... 96%
# Finalizing trickle charge...
# Charging... 98%
# Finalizing trickle charge...
# Charging... 100%
# ⚡ Battery Full! Please unplug.
# System: Protection mode active. Charging stopped.

# %%
# Out:
# Checking Battery charge...
# Checking Water...
# Checking Cleaning brush...
# Executing: Clean floor
# Executing: Water plants

# %%
import random
import time

def menu_inicio():
    # Paso 1 de tu imagen: Identificar la tarea principal / Configuración
    confirmacion = input("¿Deseas comenzar el paseo del perro ahora? (si/no): ").lower()

    if confirmacion == "si":
        print("\nRobot: 'Entendido. Iniciando protocolo de paseo...'")
        time.sleep(1)
        pasear_perro()
    else:
        print("\nRobot: 'De acuerdo. Me quedaré en la base de carga hasta que me necesites.'")

def pasear_perro():
    # Paso 2 y 3: Descomposición en subtareas y pasos específicos
    print("\n--- Fase 1: Preparación ---")
    print("1. Localizando al perro en la casa...")
    time.sleep(1)
    print("2. Coger la correa del bolsillo interior.")
    print("3. Poner la correa al perro.")
    print("4. Abrir la puerta, salir y cerrar con llave.")

    tiempo_transcurrido = 0
    objetivo_tiempo = 30
    esta_lloviendo = False

    # Ejecución de la tarea (Bucle de paseo)
    while tiempo_transcurrido < objetivo_tiempo:
        print(f"\n[Minuto {tiempo_transcurrido}] Paseando...")

        evento = random.randint(1, 10)

        if evento == 10:
            print("¡ALERTA! Ha empezado a llover.")
            esta_lloviendo = True
            break
        elif evento <= 2:
            print("Esquivando un charco.")
        elif evento == 5:
            print("Recogiendo excremento y depositándolo en la basura.")
            time.sleep(1)

        tiempo_transcurrido += 5

    # Verificación final e insumos (Paso 3 de tu imagen)
    if esta_lloviendo:
        print("\nRegreso precipitado a casa.")
        print("Robot: 'Tarea interrumpida por el clima'.")
    else:
        print(f"\nPaseo completado con éxito.")
        print("Robot: 'He completado mi tarea con éxito'.")

    print("5. Entrar, quitar correa y volver a la base de carga.")

# Llamada inicial
menu_inicio()
# Out:
# ¿Deseas comenzar el paseo del perro ahora? (si/no): si
#
# Robot: 'Entendido. Iniciando protocolo de paseo...'
#
# --- Fase 1: Preparación ---
# 1. Localizando al perro en la casa...
# 2. Coger la correa del bolsillo interior.
# 3. Poner la correa al perro.
# 4. Abrir la puerta, salir y cerrar con llave.
#
# [Minuto 0] Paseando...
#
# [Minuto 5] Paseando...
#
# [Minuto 10] Paseando...
# Esquivando un charco.
#
# [Minuto 15] Paseando...
# Esquivando un charco.
#
# [Minuto 20] Paseando...
#
# [Minuto 25] Paseando...
#
# Paseo completado con éxito.
# Robot: 'He completado mi tarea con éxito'.
# 5. Entrar, quitar correa y volver a la base de carga.

# %%
def configurar_robot(ruta, horario):
    print(f"Configurando ruta a {ruta} a las {horario}")

def verificar_insumos(articulos):
    for articulo in articulos:
        print(f"Verificando {articulo}")
    return True

def ejecutar_tareas(acciones):
    for accion in acciones:
        print(f"Haciendo: {accion}")

# Paso 1: Configuración
configurar_robot("Cocina", "10:00 AM")

# Paso 3: Verificación
listo = verificar_insumos(["Batería", "Agua"])

# Paso 2: Ejecución
if listo:
    ejecutar_tareas(["Limpiar", "Regar plantas"])
# Out:
# Configurando ruta a Cocina a las 10:00 AM
# Verificando Batería
# Verificando Agua
# Haciendo: Limpiar
# Haciendo: Regar plantas
